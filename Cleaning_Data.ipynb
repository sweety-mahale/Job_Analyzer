# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("jobs_data.csv")

# %%
df.head()
# Out:
#          job_id                                           job_role    company  \
# 0  181224917811  GN - Strategy - MC - SC&O - SC Digital Core Ar...  Accenture
# 1  181224906322                   GN - SC&O - BPM - Senior Manager  Accenture
# 2  181224906320          GN - SC&O - S&P - CLM - Associate Manager  Accenture
# 3  181224904080  GN - SONG - Service - Command Center of Future...  Accenture
# 4  181224904079                    GN - SC&O - S&P - CLM - Manager  Accenture
#
#   experience         salary                          location  rating  \
# 0    3-6 Yrs  Not disclosed     Hyderabad, Chennai, Bengaluru     3.9
# 1    2-4 Yrs  Not disclosed  Gurugram, Bengaluru, Delhi / NCR     3.9
# 2    1-5 Yrs  Not disclosed  Gurugram, Bengaluru, Delhi / NCR     3.9
# 3  12-15 Yrs  Not disclosed    New Delhi, Gurugram, Bengaluru     3.9
# 4   8-13 Yrs  Not disclosed    New Delhi, Gurugram, Bengaluru     3.9
#
#           reviews                                         key_skills  \
# ...

# %%
df.rename(columns={'key_skills': 'skills'}, inplace=True)

# %% [markdown]
# ## 1. Data Description

# %%
df.shape
# Out:
# (61773, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61773 entries, 0 to 61772
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   job_id        61773 non-null  int64
#  1   job_role      61773 non-null  object
#  2   company       41025 non-null  object
#  3   experience    60154 non-null  object
#  4   salary        61773 non-null  object
#  5   location      60663 non-null  object
#  6   rating        41029 non-null  float64
#  7   reviews       41029 non-null  object
#  8   skills        61279 non-null  object
#  9   posted_on     61773 non-null  object
#  10  job_link      61773 non-null  object
#  11  company_link  41027 non-null  object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 5.7+ MB

# %%
df.describe()
# Out:
#              job_id        rating
# count  6.177300e+04  41029.000000
# mean   1.467205e+11      3.807102
# std    4.238888e+10      0.513798
# min    1.012400e+10      1.000000
# 25%    1.212240e+11      3.600000
# 50%    1.412240e+11      3.900000
# 75%    1.812240e+11      4.000000
# max    3.110240e+11      5.000000

# %% [markdown]
# ## 2. Handling Null Value

# %%
df.isnull().sum()
# Out:
# job_id              0
# job_role            0
# company         20748
# experience       1619
# salary              0
# location         1110
# rating          20744
# reviews         20744
# skills            494
# posted_on           0
# job_link            0
# company_link    20746
# dtype: int64

# %%
df.dropna()
# Out:
#              job_id                                           job_role  \
# 0      181224917811  GN - Strategy - MC - SC&O - SC Digital Core Ar...
# 1      181224906322                   GN - SC&O - BPM - Senior Manager
# 2      181224906320          GN - SC&O - S&P - CLM - Associate Manager
# 3      181224904080  GN - SONG - Service - Command Center of Future...
# 4      181224904079                    GN - SC&O - S&P - CLM - Manager
# ...             ...                                                ...
# 61758  111224500987                       Territory Business Executive
# 61759  111224500984                                   Purchase Manager
# 61760  111224500983                               Asst Manager - Sales
# 61761  111224500982                                   Sales Consultant
# 61762  111224500968                                Front End Developer
#
#                                               company experience  \
# ...

# %% [markdown]
# #### ---->If we drop all the data which has a null value in any of the column we left with only 65% data of raw data

# %% [markdown]
# ### Replacing the Null values with "missing"

# %%
df.fillna("missing",inplace=True)
# Out:
# C:\Users\Sweety\AppData\Local\Temp\ipykernel_17772\1256532227.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'missing' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.fillna("missing",inplace=True)

# %%
df.sample(10)
# Out:
#              job_id                                           job_role  \
# 45921  131224004443                     Salesforce Application Testing
# 26929  121224501434                               Production Assistant
# 55078  121224503982                         Design Engineer (Plant 3D)
# 32015  111224917636          Project Manager-JAVA\nDevelopment Manager
# 61272  111224916538                 Business Analyst in Data Analytics
# 52950   61224904000                           Associate Data Architect
# 22201  240524010466                                Executive Assistant
# 59580  121224506138                                   Drupal Developer
# 28651  121224003727  Total Station Surveyor - Chennai,bangalore,vel...
# 45084  161224501049                 Lead Engineer Application Security
#
#                 company experience          salary  \
# 45921           missing    4-7 Yrs    6-12 Lacs PA
# 26929           missing    1-3 Yrs   Not disclosed
# ...

# %% [markdown]
# ## 3. Handling Duplicate Values

# %%
df.duplicated().sum()
# Out:
# 1185

# %%
df=df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (60588, 12)

# %% [markdown]
# ## 4. Saving the cleaned data

# %%
df.to_csv('jobs_data_preprocessed.csv', index = False)

# %%
df.to_excel("jobs_data_preprocessed.xlsx", index=False)
